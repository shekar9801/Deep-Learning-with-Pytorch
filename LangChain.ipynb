# %% [markdown]
# <a href="https://colab.research.google.com/github/shekar9801/Deep-Learning-with-Pytorch/blob/main/LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Hello!"}
  ])

print(completion.choices[0].message)

# %%
import anthropic
client = anthropic.Anthropic()

message = client.messages.create(
    model = 'claude-3-5-sonnet-20241022',
    max_tokens=1000,
    temperature=0,
    system='You are a helpful assistant.',
    messages=[
        {
            "role":"user",
            "content":[
                {
                    "type":"text",
                    "text":"Hello!"
                }
            ]
        }
    ]
)

print(message.content)

# %%
# !pip install -q langchain_openai_chat dotenv
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain_openai_chat (from versions: none)
# ERROR: No matching distribution found for langchain_openai_chat

# %%
from langchain_openai_chat import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

model = ChatOpenAI(model_name='gpt-3.5-turbo')
result = model.invoke('Hello!')
print(result.content)

# %%
from langchain_anthropic_chat import ChatAnthropic
from dotenv import load_dotenv
load_dotenv()

model = ChatAnthropic(model_name='claude-3.5-sonnet')
result = model.invoke('Hello!')
print(result.content)

# %% [markdown]
# 1. Dynamic and Reusable Prompts

# %%
from langchain_core.prompts import PromptTemplate
prompt = PromptTemplate.from_template("Summarize {topic} in a {emotion} way")
print(prompt.format(topic="dogs", emotion="happy"))
# Out:
# Summarize dogs in a happy way

# %% [markdown]
# **LangChain Architecture for Extrernal Data**

# %% [markdown]
# ![Langchain-pipeline_.webp](data:image/webp;base64,...)

# %% [markdown]
# **Memory**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Types of memories**
# 1. ConversationBufferMemory: Stores a transcript of recent messages. Great for short chats but can grow large quickly.
#
# 2. ConversationBufferWindowMemory: Only keeps the last N interactions to avoid excessive token usage.
#
# 3. Summarizer-Based Memory: Periodically summarizes older chat segments to keep a condensed memory footprint.
#
# 4. Custom Memory: For advanced use cases, you can store specialized state (e.g., the user’s preferences or key facts about them) in a custom memory class.

# %% [markdown]
# **Agents**

# %% [markdown]
# 1. LLMs

# %%
from langchain_openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

llm = OpenAI(model='gpt-turbo-3-5', temperature=0)
result = llm.invoke("what is the capital of inida?")
print(result)
# Out:
# False

# %% [markdown]
# 2. ChatModels

# %%
from langchain_openai import OpenAIChat
from dotenv import load_dotenv
load_dotenv()

chat = OpenAIChat(model='gpt-4', temperature=0)
result = chat.invoke("what is the capital of inida?")
print(result.content)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from langchain-google-genai import ChatGoogleGenAI
from dotenv import load_dotenv

load_dotenv()

chat_google = ChatGoogleGenAI(model='gemnini-1.5-pro')
result = chat_google.invoke("what is the capital of india?")
print(result.content)
